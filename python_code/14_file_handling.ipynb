# %%
f =  open("text.txt" , "r")

# %%
f.read()
# Out:
# 'i am dhruv chaudhary'

# %%
s = "i am data scientist"

# %%
f.close()

# %%
f = open("dhruv.txt" , "w" )

# %%
f.write(s)
# Out:
# 19

# %%
f.close()

# %%
#use "with" statement

with open("dhruv.txt" , "r") as file:
    content = file.read()
    print(content)
# Out:
# i am data scientist

# %%
with open("dhruv.txt") as file:
    for line in file:
        print(line.strip())
# Out:
# i am data scientist

# %%
with open('dhruv.txt', 'a') as d:
    d.write("\ni love computer")

with open('dhruv.txt', 'r') as d:
    print(d.read())
# Out:
# i am data scientist
# i love computer

# %%
with open('dhruv.txt', 'r') as d:
    print(d.read())
# Out:
# i am data scientist
# i love computer

# %%
import os
os.path.exists("dhruv.txt")
# Out:
# True
