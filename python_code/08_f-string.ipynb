# %%
name = "Dhruv"
Age = 22

# %%
print(f"my name is {name} and i am currently {Age} year old")
# Out:
# my name is Dhruv and i am currently 22 year old

# %%
pi = 3.14159
print(f"short value of pi : {pi:.2f}")
# Out:
# short value of pi : 3.14

# %%
print(f"{'python' :<10}")
print(f"{'python' :>10}")
print(f"{'python' :^10}")
# Out:
# python
#     python
#   python
