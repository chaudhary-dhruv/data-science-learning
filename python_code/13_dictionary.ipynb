# %%
d = {}

# %%
type(d)
# Out:
# dict

# %%
student = {
    "name" : "dhruv",
    "age" : 25,
    "marks" : 95
}

# %%
student["name"]
# Out:
# 'dhruv'

# %%
student["name4"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 student["name4"]
#
# KeyError: 'name4'

# %%
r = student.get("name2")

# %%
print(r)
# Out:
# None

# %%
student["age"] = 19

#value change

# %%
student
# Out:
# {'name': 'dhruv', 'age': 19, 'marks': 95}

# %%
student.keys()
# Out:
# dict_keys(['name', 'age', 'marks'])

# %%
student.values()
# Out:
# dict_values(['dhruv', 19, 95])

# %%
student.items()
# Out:
# dict_items([('name', 'dhruv'), ('age', 19), ('marks', 95)])

# %%
student.update({"name" : "gopal"})

# %%
student
# Out:
# {'name': 'gopal', 'age': 19, 'marks': 95}

# %%
student.update({"name" : "gopi" , "language" : "kotlin"})

# %%
student
# Out:
# {'name': 'gopi', 'age': 19, 'marks': 95, 'language': 'kotlin'}

# %%
student.pop("marks")
# Out:
# 95

# %%
student
# Out:
# {'name': 'gopi', 'age': 19, 'language': 'kotlin'}

# %%
student.popitem()
# Out:
# ('language', 'kotlin')

# %%
student
# Out:
# {'name': 'gopi', 'age': 19}

# %%
student.setdefault("city","unknown")
# Out:
# 'unknown'
