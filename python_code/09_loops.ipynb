# %%
l = ["apple" , "banana" , "grapes" , "kiwi"]

# %%
for friuts in l:
    print(friuts)
# Out:
# apple
# banana
# grapes
# kiwi

# %%
m = ["apple" , "banana" , "grapes" , "kiwi"]
for friut in m:
    if(friut == "grapes"):
        break
    print(friut)
# Out:
# apple
# banana

# %%
for fruit in m:
    pass
print("hello")
# Out:
# hello

# %%
m = ["apple" , "banana" , "grapes" , "kiwi"]
for friut in m:
    if(friut == "grapes"):
        continue
    print(friut)
# Out:
# apple
# banana
# kiwi
