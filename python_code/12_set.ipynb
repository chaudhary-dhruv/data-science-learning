# %%
a = {}

# %%
type(a)
# Out:
# dict

# %%
b = set()

# %%
type(b)
# Out:
# set

# %%
c = {1,2,4,5,5,67,7,88,89}

# %%
print(c)
# Out:
# {1, 2, 67, 4, 5, 7, 88, 89}

# %%
unique = set([12,34,5,90,76,7,8,78,86,43,2,8])

# %%
print(unique)
# Out:
# {34, 2, 5, 7, 8, 43, 12, 76, 78, 86, 90}

# %%
type(unique)
# Out:
# set

# %%
unique.remove(88)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 unique.remove(88)
#
# KeyError: 88

# %%
    unique
# Out:
# {2, 5, 7, 8, 12, 34, 43, 76, 78, 86, 90}

# %%
unique.discard(88)

#remove give the error ,if element doesn't exist in set
#discard do not give the error ,if element doesn't exist in set

# %%
unique
# Out:
# {2, 5, 7, 8, 12, 34, 43, 76, 78, 86, 90}

# %%
unique.pop()
# Out:
# 34

# %%
unique
# Out:
# {2, 5, 7, 8, 12, 43, 76, 78, 86, 90}

# %%
new = unique.copy()

# %%
new
# Out:
# {2, 5, 7, 8, 12, 43, 76, 78, 86, 90}

# %%
old = new.clear()

# %%
old

# %%
type(old)
# Out:
# NoneType

# %%
set1 = {1,2,3,4}
set2 = {3,4,5,6}

# %%
set1.union(set2)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
print(set1 | set2)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
set1.intersection(set2)
# Out:
# {3, 4}

# %%
print(set1 & set2)
# Out:
# {3, 4}

# %%
set1.difference(set2)
# Out:
# {1, 2}

# %%
print(set1 - set2)
# Out:
# {1, 2}

# %%
set1.symmetric_difference(set2)
# Out:
# {1, 2, 5, 6}

# %%
print(set1 ^ set2)
# Out:
# {1, 2, 5, 6}

# %%
set1.issubset(set2)
# Out:
# False

# %%
set1.issuperset(set2)
# Out:
# False
