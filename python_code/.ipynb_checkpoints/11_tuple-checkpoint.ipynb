# %%
t = ()

# %%
type(t)
# Out:
# tuple

# %%
t= (56,31,12,35,87,34)

# %%
t[4]
# Out:
# 87

# %%
print(t)
# Out:
# (56, 31, 12, 35, 87, 34)

# %%
t[1] = 67
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 t[1] = 67
#
# TypeError: 'tuple' object does not support item assignment

# %%
print(t[1:4])   

#slicing
# Out:
# (31, 12, 35)

# %%
#packing
person = (36 , "dhruv" , "Data Engineer")

#unpacking
age,name,profesion = person

# %%
age
# Out:
# 36

# %%
name
# Out:
# 'dhruv'

# %%
profesion
# Out:
# 'Data Engineer'

# %%
t.index(87)
# Out:
# 4

# %%
t.count(87)
# Out:
# 1

# %%
single_tuple = (4,) 

#comma is necessary in single tuple , if we don't add comma it's represent the 'int'

# %%
print(single_tuple)
# Out:
# (4,)

# %%
type(single_tuple)
# Out:
# tuple

# %%
multi_tuple = (4 , "master" , True)

# %%
print(multi_tuple)
# Out:
# (4, 'master', True)
