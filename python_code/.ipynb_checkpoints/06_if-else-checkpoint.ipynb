# %%
a = 10

# %%
if(a > 12):
    print("Greater")
else:
    print("Smaller")
# Out:
# Smaller

# %%
a = 41
if a>50:
    print("greater than 50")
elif (a > 40):
    print("greater than 40")
elif (a > 30):
    print("grater than 30")
else:
    print("done")
# Out:
# greater than 40
