# %%
import pandas as pd

# %%
print("Hello Friends")
# Out:
# Hello Friends

# %%
import numpy as np

# %%
print("Nothing did today")
# Out:
# Nothing did today

# %%
print("Today date is 17 and i do nothing" )
# Out:
# Today date is 17 and i do nothing

# %%
print("From tomorrow i will start the data visualization ")
# Out:
# From tomorrow i will start the data visualization

# %%
df = [1,2,3,4,5,6,7,8]

# %%
df[7]
# Out:
# 8
