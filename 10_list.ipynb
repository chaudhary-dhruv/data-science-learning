# %%
l = [2,45,7,34,6,32,5,9]

# %%
print(l)
# Out:
# [2, 45, 7, 34, 6, 32, 5, 9]

# %%
l.append(12)

# %%
l
# Out:
# [2, 45, 7, 34, 6, 32, 5, 9, 12]

# %%
l.remove(7)

# %%
l
# Out:
# [2, 45, 34, 6, 32, 5, 9, 12]

# %%
l2 = [78,90]

# %%
l.extend(l2)

# %%
l
# Out:
# [2, 45, 34, 6, 32, 5, 9, 12, 78, 90]

# %%
l.insert(4,31)

# %%
l
# Out:
# [2, 45, 34, 6, 31, 32, 5, 9, 12, 78, 90]

# %%
l.pop(2)
# Out:
# 6

# %%
l.pop(2)
# Out:
# 34

# %%
l
# Out:
# [2, 45, 6, 31, 32, 5, 9, 12, 78, 90]

# %%
l.count(9)
# Out:
# 1

# %%
l.sort()

# %%
l
# Out:
# [2, 5, 9, 12, 31, 32, 45, 78, 90]

# %%
l.reverse()

# %%
l
# Out:
# [90, 78, 45, 32, 31, 12, 9, 5, 2]

# %%
newList = [23,9,3,4,7,1,6,8,4]
sorted(newList)
# Out:
# [1, 3, 4, 4, 6, 7, 8, 9, 23]

# %%
newList
# Out:
# [23, 9, 3, 4, 7, 1, 6, 8, 4]

# %%
l.clear()

# %%
l
# Out:
# []

# %%
l.append(1)

# %%
l
# Out:
# [1]

# %%
d = [2, 3,5, "master" , 45,21,[4,9]]

#nested list

# %%
d
# Out:
# [2, 3, 5, 'master', 45, 21, [4, 9]]

# %%
d[4]
# Out:
# 45

# %%
d[3]
# Out:
# 'master'

# %%
d[6]
# Out:
# [4, 9]

# %%
d[6][1]
# Out:
# 9

# %%
list1 = [3,6,2,9,1]

# %%
list2 = [45,23,56,44]

# %%
f= list1 + list2

# %%
f
# Out:
# [3, 6, 2, 9, 1, 45, 23, 56, 44]

# %%
list1
# Out:
# [3, 6, 2, 9, 1]

# %%
if 56 in f:
    print("yes")
# Out:
# yes

# %%
name = "dhruv-gopu-himanshi-komal-jay-mayur-arav"

# %%
name.split("-")
# Out:
# ['dhruv', 'gopu', 'himanshi', 'komal', 'jay', 'mayur', 'arav']
