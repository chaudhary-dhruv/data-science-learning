# %%
code = 5000

# %%
match code:
    case 200:
        print("OK")
    case 400:
        print("bad responce")
    case 500:
        print("server side error")
    case _:
        print("nothing match")

print("ALL DONE!!!")
# Out:
# nothing match
# ALL DONE!!!
