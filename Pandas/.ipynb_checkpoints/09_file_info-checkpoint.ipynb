# %%
import pandas as pd

# %%
# read csv file

df = pd.read_csv("bollywood_data.csv")

# %%
df
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR crore)  IMDb
# ...

# %%
# read specific part of data

new_data = pd.read_csv("bollywood_data.csv", usecols=["Actor", "IMDb"], nrows=5)

# %%
new_data
# Out:
#             Actor  IMDb
# 0  Shah Rukh Khan   7.2
# 1     Salman Khan   6.0
# 2      Aamir Khan   8.4
# 3   Ranbir Kapoor   5.6
# 4   Ranveer Singh   7.0

# %%
# write csv

df.to_csv("bollywood_output.csv" , index=False)

# %% [markdown]
# # Excel File

# %%
 df = pd.read_excel("data.xlsx")

# %%
df
# Out:
#   Student School  marks
# 0   Dhruv    LJS     97
# 1    Jack    PUS     45
# 2  Denial    RJD     45
# 3    Rock    BJS     78
# 4   Roman    RCS     66
# 5  Lisban    CKP     90
# 6   khali    WBK     39
# 7   Muzan    CRS     61

# %%
 df = pd.read_excel("data.xlsx" , sheet_name="College_student")

# %%
df
# Out:
#   Student College  sem
# 0  Mahesh     RJD    1
# 1    Babu    PDEU    5

# %%
# Write Excel

# df.to_excel("output.xlsx", index=False)

# %%
# Write Excel sheet wise

with pd.ExcelWriter("Final_Excel.xlsx") as writter:
    new_data.to_excel(writter , sheet_name="bollywood" , index=False)
    df.to_excel(writter , sheet_name="college" , index=False)

# %% [markdown]
# # JSON file

# %%
df = pd.read_json("data.json")

# %%
df
# Out:
#    id   product  price
# 0   1    Laptop   1200
# 1   2     Mouse     25
# 2   3  Keyboard     75
